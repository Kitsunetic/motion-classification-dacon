# %%
# %load_ext lab_black

# %%
import pandas as pd
from multiprocessing.dummy import Pool
import math

import numpy as np
from tqdm import tqdm
from pathlib import Path
from collections import defaultdict
import random
import matplotlib.pyplot as plt

from scipy.ndimage.filters import gaussian_filter

# %%
data = np.load("data/0203.npz")

# %%
X_train, Y_train, X_test = data["X_train"], data["Y_train"], data["X_test"]

# %%
out_dir = Path("data/0206")
out_dir.mkdir(parents=True, exist_ok=True)

train_dir = out_dir / "train"
test_dir = out_dir / "test"
train_dir.mkdir(parents=True, exist_ok=True)
test_dir.mkdir(parents=True, exist_ok=True)

# %%
X_train.shape
# Out:
# (3125, 18, 600)

# %%
plt.plot(X_train[3, 11, :])

# %%
X_train[0, 11, 0], X_train[0, 11, -1]
# Out:
# (0.15013326667068988, 0.0648963265767909)

# %%
x = X_train[0, 0, :]

# %%
x.mean(), x.std()
# Out:
# (-2.983975476430108e-07, 1.0000000032330092)

# %%
z = (x - x.mean()) / x.std()

# %%
plt.figure(figsize=(8, 6))
plt.plot(z, ".-")
plt.tight_layout()
plt.show()

# %%
z[0], z[-1]
# Out:
# (1.4361175852050667, 1.0810714332843916)

# %%
x = X_train[3, 11, :]

# %%
x = np.concatenate([x, x[:300]])

# %%
plt.figure(figsize=(8, 6))
plt.plot(x[500:700], ".")
plt.tight_layout()
plt.show()
